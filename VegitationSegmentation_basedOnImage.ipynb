# %% [markdown]
# <a href="https://colab.research.google.com/github/erfanera/SlumImprovment/blob/main/VegitationSegmentation_basedOnImage.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install segment-geospatial groundingdino-py leafmap localtileserver
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.8/50.8 kB 937.1 kB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.3/82.3 kB 1.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 13.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 49.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.2/40.2 kB 5.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 6.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.6/20.6 MB 43.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 79.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 254.7/254.7 kB 33.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.6/108.6 kB 16.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 79.2 MB/s eta 0:00:00
# ...

# %%
import leafmap
from samgeo import tms_to_geotiff
from samgeo.text_sam import LangSAM

bbox = [72.8488, 19.0384, 72.8604, 19.0484]

# %%
m = leafmap.Map(center=[19.0384,72.8488 ], zoom=18, height="800px")
m.add_basemap("SATELLITE")
m
# Out:
# Map(center=[19.0384, 72.8488], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zo…

# %%
bbox = m.user_roi_bounds()

# %%
image = "root/splitImage01_Original.png"
#tms_to_geotiff(output=image, bbox=bbox, zoom=19, source="Satellite", overwrite=True)
sam = LangSAM()
# Out:
# GroundingDINO_SwinB.cfg.py:   0%|          | 0.00/1.01k [00:00<?, ?B/s]
# final text_encoder_type: bert-base-uncased
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# groundingdino_swinb_cogcoor.pth:   0%|          | 0.00/938M [00:00<?, ?B/s]
# Downloading: "https://dl.fbaipublicfiles.com/segment_anything/sam_vit_h_4b8939.pth" to /root/.cache/torch/hub/checkpoints/sam_vit_h_4b8939.pth
# 100%|██████████| 2.39G/2.39G [00:13<00:00, 194MB/s]

# %%
text_prompt = "tree"
sam.predict(image, text_prompt, box_threshold=0.24, text_threshold=0.24)

sam.show_anns(
    cmap='Greens',
    box_color='red',
    title='Automatic Segmentation of Trees',
    blend=True,
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-4f30b53c4031> in <cell line: 2>()
#       1 text_prompt = "tree"
# ----> 2 sam.predict(image, text_prompt, box_threshold=0.24, text_threshold=0.24)
#       3
#       4 sam.show_anns(
#       5     cmap='Greens',
#
# /usr/local/lib/python3.10/dist-packages/samgeo/text_sam.py in predict(self, image, text_prompt, box_threshold, text_threshold, output, mask_multiplier, dtype, save_args, return_results, return_coords, **kwargs)
#     264
#     265             if not os.path.exists(image):
# --> 266                 raise ValueError(f"Input path {image} does not exist.")
#     267
#     268             self.source = image
#
# ValueError: Input path root/splitImage01_Original.png does not exist.
